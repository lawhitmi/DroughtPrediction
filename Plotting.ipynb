# %%
import matplotlib.pyplot as plt
import netCDF4 as nc
import numpy as np
from cartopy import config
import cartopy.crs as ccrs

# %%
data = nc.Dataset('Data/psl_train.nc')

# %%
data
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_64BIT_OFFSET data model, file format NETCDF3):
#     CDI: Climate Data Interface version 1.9.8 (https://mpimet.mpg.de/cdi)
#     Conventions: CF-1.6
#     history: Thu Nov 05 21:22:06 2020: cdo -C no -g grid -f nc copy psl_train psl_train.nc
#     CDO: Climate Data Operators version 1.9.8 (https://mpimet.mpg.de/cdo)
#     dimensions(sizes): time(900), lon(43), lat(54)
#     variables(dimensions): float64 time(time), float64 lon(lon), float64 lat(lat), float32 var1(time,lat,lon)
#     groups:

# %%
lat = data.variables['lat'][:]
lon = data.variables['lon'][:]
press = data.variables['var1'][50,:,:]

# %%
plt.figure(figsize=(15,15))
ax = plt.axes(projection=ccrs.PlateCarree())
plt.contourf(lon, lat, press, 50,
             transform=ccrs.PlateCarree())
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=2, color='gray', alpha=0.5, linestyle='--')
ax.coastlines()
plt.colorbar()
plt.title('Sea-Level Pressure Fields', fontsize=16)
plt.show()

# %%
datatemp = nc.Dataset('Data/tas_train.nc')

# %%
datatemp
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_64BIT_OFFSET data model, file format NETCDF3):
#     CDI: Climate Data Interface version 1.9.8 (https://mpimet.mpg.de/cdi)
#     Conventions: CF-1.6
#     history: Sun Nov 01 22:39:25 2020: cdo -C no -g grid -f nc copy tas_train tas_train.nc
#     CDO: Climate Data Operators version 1.9.8 (https://mpimet.mpg.de/cdo)
#     dimensions(sizes): time(900), lon(43), lat(54)
#     variables(dimensions): float64 time(time), float64 lon(lon), float64 lat(lat), float32 var1(time,lat,lon)
#     groups:

# %%
lat = datatemp.variables['lat'][:]
lon = datatemp.variables['lon'][:]
temp = datatemp.variables['var1'][50,:,:]

# %%
plt.figure(figsize=(15,15))
ax = plt.axes(projection=ccrs.PlateCarree())
plt.contourf(lon, lat, temp, 50,
             transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=2, color='gray', alpha=0.5, linestyle='--')
plt.colorbar()
plt.title('Near-Surface Temperature Fields', fontsize=16)
plt.show()

# %%
nao
